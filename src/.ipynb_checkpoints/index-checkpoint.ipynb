# %% [markdown]
# https://worldhappiness.report/ed/2021/

# %% [markdown]
# Imports

# %%
# Importing all the project pre-requisites
import pandas as pd
import numpy as np
from matplotlib import pyplot
# %matplotlib inline

# %%
# Read in data from the main data excel file
data = pd.read_excel('../data/DataPanelWHR2021C2.xls', sheet_name = 'Sheet1')

# Rename the year column
data.rename(columns = {'year':'Year'}, inplace = True)

# Extract the reigonal indicator column from figure data excel file
fig_data = pd.read_excel('../data/DataForFigure2.1WHR2021C2.xls', sheet_name = 'Sheet1')
region = pd.DataFrame(fig_data[["Country name","Regional indicator"]])  # extracting region information

# Merge the reigonal indicator column into the main data set
data = data.merge(region, on='Country name', how='left') # inserting region indicator column
col = list(data)
col.insert(1,col.pop(col.index('Regional indicator')))
data = data.loc[:,col]
data['Regional indicator'].fillna("None", inplace=True)

data
# Out:
#      Country name  Regional indicator  Year  Life Ladder  Log GDP per capita  \
# 0     Afghanistan          South Asia  2008     3.723590            7.370100
# 1     Afghanistan          South Asia  2009     4.401778            7.539972
# 2     Afghanistan          South Asia  2010     4.758381            7.646709
# 3     Afghanistan          South Asia  2011     3.831719            7.619532
# 4     Afghanistan          South Asia  2012     3.782938            7.705479
# ...           ...                 ...   ...          ...                 ...
# 1944     Zimbabwe  Sub-Saharan Africa  2016     3.735400            7.984372
# 1945     Zimbabwe  Sub-Saharan Africa  2017     3.638300            8.015738
# 1946     Zimbabwe  Sub-Saharan Africa  2018     3.616480            8.048798
# 1947     Zimbabwe  Sub-Saharan Africa  2019     2.693523            7.950132
# 1948     Zimbabwe  Sub-Saharan Africa  2020     3.159802            7.828757
#
#       Social support  Healthy life expectancy at birth  \
# 0           0.450662                         50.799999
# 1           0.552308                         51.200001
# 2           0.539075                         51.599998
# 3           0.521104                         51.919998
# 4           0.520637                         52.240002
# ...              ...                               ...
# 1944        0.768425                         54.400002
# 1945        0.754147                         55.000000
# 1946        0.775388                         55.599998
# 1947        0.759162                         56.200001
# 1948        0.717243                         56.799999
#
#       Freedom to make life choices  Generosity  Perceptions of corruption  \
# 0                         0.718114    0.167640                   0.881686
# 1                         0.678896    0.190099                   0.850035
# 2                         0.600127    0.120590                   0.706766
# 3                         0.495901    0.162427                   0.731109
# 4                         0.530935    0.236032                   0.775620
# ...                            ...         ...                        ...
# 1944                      0.732971   -0.094634                   0.723612
# 1945                      0.752826   -0.097645                   0.751208
# 1946                      0.762675   -0.068427                   0.844209
# 1947                      0.631908   -0.063791                   0.830652
# 1948                      0.643303   -0.008696                   0.788523
#
#       Positive affect  Negative affect
# 0            0.517637         0.258195
# 1            0.583926         0.237092
# 2            0.618265         0.275324
# 3            0.611387         0.267175
# 4            0.710385         0.267919
# ...               ...              ...
# 1944         0.737636         0.208555
# 1945         0.806428         0.224051
# 1946         0.710119         0.211726
# 1947         0.716004         0.235354
# 1948         0.702573         0.345736
#
# [1949 rows x 12 columns]

# %%
data.describe() #Check the Summary Statistics
# Out:
#               Year  Life Ladder  Log GDP per capita  Social support  \
# count  1949.000000  1949.000000         1913.000000     1936.000000
# mean   2013.216008     5.466707            9.368459        0.812553
# std       4.166828     1.115717            1.154091        0.118480
# min    2005.000000     2.375092            6.635322        0.290184
# 25%    2010.000000     4.640079            8.463744        0.749390
# 50%    2013.000000     5.386025            9.460323        0.835167
# 75%    2017.000000     6.283498           10.352778        0.905291
# max    2020.000000     8.018934           11.648169        0.987343
#
#        Healthy life expectancy at birth  Freedom to make life choices  \
# count                       1894.000000                   1917.000000
# mean                          63.359375                      0.742567
# std                            7.510244                      0.142104
# min                           32.299999                      0.257534
# 25%                           58.685000                      0.647048
# 50%                           65.199997                      0.763476
# 75%                           68.589998                      0.856030
# max                           77.099998                      0.985178
#
#         Generosity  Perceptions of corruption  Positive affect  \
# count  1860.000000                1839.000000      1927.000000
# mean      0.000108                   0.747111         0.709998
# std       0.162221                   0.186793         0.107106
# min      -0.335040                   0.035198         0.321690
# 25%      -0.112973                   0.690305         0.625373
# 50%      -0.025393                   0.802428         0.722391
# 75%       0.090967                   0.871942         0.799276
# max       0.698099                   0.983276         0.943621
#
#        Negative affect
# count      1933.000000
# mean          0.268552
# std           0.085176
# min           0.082737
# 25%           0.206403
# 50%           0.258117
# 75%           0.319716
# max           0.704590
